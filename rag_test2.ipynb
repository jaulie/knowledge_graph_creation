# %% [markdown]
# # Initial Setup

# %%
import json
from collections import Counter

with open("/Users/brianmann/Downloads/ori_pqal.json", "r") as f:
    json_data = json.load(f)

questions = [entry.get("QUESTION", "N/A") for entry in json_data.values()]
answer_key = [entry.get("final_decision", "N/A") for entry in json_data.values()]

num_questions = 50

# %% [markdown]
# # Clear and Load Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j connection credentials
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "sunsh1ne1"

# Initialize the Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

# Function to clear the graph and insert the data into Neo4j
def insert_data_to_neo4j(data):
    with driver.session() as session:
        # Clear all nodes and relationships
        session.run("MATCH (n) DETACH DELETE n")

        # Insert new data from the file
        for line in data:
            line.replace("((", "(").replace("))", ")").replace('"', '').replace("'", "")
            # Split each line by ' -[:' to get the nodes and relationship type
            parts = line.strip().split(' -[:')
            node_1 = parts[0][1:-1]  # Remove parentheses
            relationship_and_node_2 = parts[1].split(']->')
            relationship = relationship_and_node_2[0]
            node_2 = relationship_and_node_2[1][1:-1]  # Remove parentheses

            # Create the nodes and relationships
            cypher_query = f"""
            MERGE (a:Entity {{name: '{node_1}'}})
            MERGE (b:Entity {{name: '{node_2}'}})
            MERGE (a)-[:{relationship}]->(b)
            """
            session.run(cypher_query)

# Read the graph data from the file
with open("graph_output.txt", "r") as file:
    data = file.readlines()

# Insert the data into Neo4j
insert_data_to_neo4j(data)

print("Data inserted into Neo4j successfully.")
# Out:
# Data inserted into Neo4j successfully.

# %% [markdown]
# # Test Individual Questions

# %%
from neo4j import GraphDatabase
from fuzzywuzzy import fuzz
from langchain_ollama import ChatOllama
import re
import itertools

# Neo4j connection credentials
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "sunsh1ne1"

# Initialize the Neo4j driver
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

#Relationships and their corresponding answers
relationship_to_answer = {
    "CAUSES": "Yes",
    "DOES_NOT_CAUSE": "No",
    "TREATS": "Yes",
    "DOES_NOT_TREAT": "No",
    "DIAGNOSES": "Maybe",
    "DOES_NOT_DIAGNOSE": "No",
    "REDUCES_RISK_OF": "No",
    "INCREASES_RISK_OF": "No",
    "IS_A_RISK_FACTOR_FOR": "No",
    "IS_NOT_A_RISK_FACTOR_FOR": "Yes",
    "IS_ASSOCIATED_WITH": "Yes",
    "IS_NOT_ASSOCIATED_WITH": "No",
    "PREDICTS": "Maybe",
    "DOES_NOT_PREDICT": "No",
    "IS_AS_EFFECTIVE_AS": "Yes",
    "IS_LESS_EFFECTIVE_THAN": "No",
    "IS_MORE_EFFECTIVE_THAN": "Yes",
    "IMPROVES": "Yes",
    "WORSENS": "No",
    "IS_COST_EFFECTIVE_FOR": "Yes",
    "IS_NOT_COST_EFFECTIVE_FOR": "No",
    "INFLUENCES": "Yes",
    "DOES_NOT_INFLUENCE": "No",
    "IS_USEFUL_FOR": "Yes",
    "IS_NOT_USEFUL_FOR": "No"
}

# Extract entities from the question using LLM
def extract_entities_from_question(question):
    llm = ChatOllama(model="llama3.2", temperature=0, max_tokens=2048)
    query = f'''
    Please identify the most meaningful entities which could be used to answer the following question: "{question}"
    Put the answer on one line.
    Use as many of the words in the question in the nodes as possible. Start the list with START and end with the word FINISHED.
    So the final answer with be like START Entity1, Entity2, ... FINISHED
    '''
    response = llm.invoke(query)
    raw_output = response.content.strip()
    print(raw_output)
    # matches = re.findall(r'START\s*,\s*(.*?)\s*,\s*FINISHED', raw_output)
    # matches = re.findall(r'START\s*,\s*(.*?)\s*FINISHED', raw_output)
    matches = re.findall(r'START\s+(.*?)\s*FINISHED', raw_output)

    if matches:
        return [entity.strip() for entity in matches[0].split(',')]
    return []

# Fuzzy match to the best graph node
def fuzzy_match_entity(entity, entity_db, threshold=80):
    best_match = None
    highest_score = 0
    for db_entity in entity_db:
        score = fuzz.partial_ratio(entity.lower(), db_entity.lower())
        if score > highest_score and score >= threshold:
            best_match = db_entity
            highest_score = score
    return best_match

# Look for relationships in either direction
def search_relationships_in_neo4j(entity_1, entity_2):
    with driver.session() as session:
        query = """
        MATCH (a:Entity {name: $entity_1})-[r]-(b:Entity {name: $entity_2})
        RETURN DISTINCT type(r) AS relationship_type;
        """
        result = session.run(query, entity_1=entity_1, entity_2=entity_2)
        return [record["relationship_type"] for record in result]

# Map to answer
def determine_answer_from_relationship(relationship_type):
    return relationship_to_answer.get(relationship_type, "Maybe")

# Find relationships for all pairs of entities
def answer_question(question):
    entities = extract_entities_from_question(question)
    print(entities)

    if len(entities) < 2:
        print("Could not extract enough entities.")
        return "Maybe"

    with driver.session() as session:
        query = "MATCH (n:Entity) RETURN n.name AS name"
        result = session.run(query)
        entity_db = [record["name"] for record in result]

    # Fuzzy match all entities once
    matched_entities = {
        entity: fuzzy_match_entity(entity, entity_db)
        for entity in entities
    }

    for e in matched_entities:
        if matched_entities[e] is None:
            print(f"No match for entity: {e}")

    # Get all combinations of 2 entities (ordered pairs)
    combinations = itertools.permutations(entities, 2)

    answers = []

    for ent1, ent2 in combinations:
        matched_1 = matched_entities.get(ent1)
        matched_2 = matched_entities.get(ent2)

        if matched_1 and matched_2:
            print(f"Checking: {matched_1} <-> {matched_2}")
            relationships = search_relationships_in_neo4j(matched_1, matched_2)

            if relationships:
                print(f"  Found relationships: {relationships}")
                for r in relationships:
                    answer = determine_answer_from_relationship(r)
                    print(answer)
                    if answer != "Maybe":
                        answers.append(answer)

    if answers:
        most_common = Counter(answers).most_common(1)[0][0]
        print(f"Most common answer: {most_common}")
        return most_common

    print("No definitive relationship found.")
    return "Maybe"

#TESTs
# Example question
question = "Do mitochondria play a role in remodelling lace plant leaves during programmed cell death?"
# question = "Are the long-term results of the transanal pull-through equal to those of the transabdominal pull-through?"
# question = "Syncope during bathing in infants, a pediatric form of water-induced urticaria?"

entities = extract_entities_from_question(question)
print(f"Extracted Entities: {entities}")

answer = answer_question(question)
print(f"Answer: {answer}")
# Out:
# START Mitochondria, programmed cell death, lace plant leaves, remodelling, cell death, programmed cell death, mitochondria, remodelling, programmed cell death, leaf senescence, programmed cell death, mitochondrial dynamics, programmed cell death, apoptosis, programmed cell death, cellular remodeling, programmed cell death, mitochondrial function, programmed cell death, leaf abscission, programmed cell death, remodelling, programmed cell death FINISHED
# Extracted Entities: ['Mitochondria', 'programmed cell death', 'lace plant leaves', 'remodelling', 'cell death', 'programmed cell death', 'mitochondria', 'remodelling', 'programmed cell death', 'leaf senescence', 'programmed cell death', 'mitochondrial dynamics', 'programmed cell death', 'apoptosis', 'programmed cell death', 'cellular remodeling', 'programmed cell death', 'mitochondrial function', 'programmed cell death', 'leaf abscission', 'programmed cell death', 'remodelling', 'programmed cell death']
# START Mitochondria, programmed cell death, lace plant leaves, remodelling, cell death, programmed cell death, mitochondria, remodelling, programmed cell death, leaf senescence, programmed cell death, mitochondrial dynamics, programmed cell death, apoptosis, programmed cell death, cellular remodeling, programmed cell death, mitochondrial function, programmed cell death, leaf abscission, programmed cell death, remodelling, programmed cell death FINISHED
# ['Mitochondria', 'programmed cell death', 'lace plant leaves', 'remodelling', 'cell death', 'programmed cell death', 'mitochondria', 'remodelling', 'programmed cell death', 'leaf senescence', 'programmed cell death', 'mitochondrial dynamics', 'programmed cell death', 'apoptosis', 'programmed cell death', 'cellular remodeling', 'programmed cell death', 'mitochondrial function', 'programmed cell death', 'leaf abscission', 'programmed cell death', 'remodelling', 'programmed cell death']
# No match for entity: leaf senescence
# No match for entity: apoptosis
# No match for entity: cellular remodeling
# No match for entity: leaf abscission
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Most common answer: Yes
# Answer: Yes

# %% [markdown]
# # Generate Answers

# %%
# Function to generate answers using the provided code
def generate_answers_for_questions(questions, num_questions):
    answers = []
    
    for i in range(min(num_questions, len(questions))):
        question = questions[i]
        print(f"Processing question: {question}")
        # Generate the answer using the existing function
        answer = answer_question(question)  # This is your provided function
        answers.append(answer)
        
    return answers

# Generate answers for the first 20 questions
generated_answers = generate_answers_for_questions(questions, num_questions)
# Out:
# Processing question: Do mitochondria play a role in remodelling lace plant leaves during programmed cell death?
# START Mitochondria, programmed cell death, lace plant leaves, remodelling, cell death, programmed cell death, mitochondria, remodelling, programmed cell death, leaf senescence, programmed cell death, mitochondrial dynamics, programmed cell death, apoptosis, programmed cell death, cellular remodeling, programmed cell death, mitochondrial function, programmed cell death, leaf abscission, programmed cell death, remodelling, programmed cell death FINISHED
# ['Mitochondria', 'programmed cell death', 'lace plant leaves', 'remodelling', 'cell death', 'programmed cell death', 'mitochondria', 'remodelling', 'programmed cell death', 'leaf senescence', 'programmed cell death', 'mitochondrial dynamics', 'programmed cell death', 'apoptosis', 'programmed cell death', 'cellular remodeling', 'programmed cell death', 'mitochondrial function', 'programmed cell death', 'leaf abscission', 'programmed cell death', 'remodelling', 'programmed cell death']
# No match for entity: leaf senescence
# No match for entity: apoptosis
# No match for entity: cellular remodeling
# No match for entity: leaf abscission
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> Mitochondria
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: Mitochondria <-> (remodelling of lace plant leaves
# Checking: Mitochondria <-> (programmed cell death in lace plant leaves
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> Mitochondria
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (remodelling of lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> Mitochondria
#   Found relationships: ['CAUSES']
# Yes
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (programmed cell death in lace plant leaves
# Checking: (programmed cell death in lace plant leaves <-> (remodelling of lace plant leaves
# Most common answer: Yes
# Processing question: Landolt C and snellen e acuity: differences in strabismus amblyopia?
# START Strabismus, Amblyopia, Landolt C, Snellen E Acuity, Ophthalmology, Optometry, Vision Therapy, Pediatric Ophthalmology, Neurology, Psychology, Eye Care, Orthoptics, Visual Development, Binocular Vision, Refractive Errors, Atropine, Cycloplegia, Mydriasis, Pupil Distance, Corneal Topography, Autorefraction, Keratometry, Retinoscopy, Visual Field Testing, Perimetry, Electroretinography, Electrophysiology, Neuroplasticity, Rehabilitation, Treatment Outcomes, Research Studies, Clinical Trials, Evidence-Based Medicine, Guidelines, Standards, FINISHED
# ['Strabismus', 'Amblyopia', 'Landolt C', 'Snellen E Acuity', 'Ophthalmology', 'Optometry', 'Vision Therapy', 'Pediatric Ophthalmology', 'Neurology', 'Psychology', 'Eye Care', 'Orthoptics', 'Visual Development', 'Binocular Vision', 'Refractive Errors', 'Atropine', 'Cycloplegia', 'Mydriasis', 'Pupil Distance', 'Corneal Topography', 'Autorefraction', 'Keratometry', 'Retinoscopy', 'Visual Field Testing', 'Perimetry', 'Electroretinography', 'Electrophysiology', 'Neuroplasticity', 'Rehabilitation', 'Treatment Outcomes', 'Research Studies', 'Clinical Trials', 'Evidence-Based Medicine', 'Guidelines', 'Standards', '']
# No match for entity: Ophthalmology
# No match for entity: Optometry
# No match for entity: Pediatric Ophthalmology
# No match for entity: Eye Care
# No match for entity: Visual Development
# No match for entity: Binocular Vision
# No match for entity: Refractive Errors
# No match for entity: Atropine
# No match for entity: Cycloplegia
# No match for entity: Mydriasis
# No match for entity: Pupil Distance
# No match for entity: Corneal Topography
# No match for entity: Autorefraction
# No match for entity: Keratometry
# No match for entity: Retinoscopy
# No match for entity: Visual Field Testing
# No match for entity: Perimetry
# No match for entity: Electroretinography
# No match for entity: Electrophysiology
# No match for entity: Neuroplasticity
# No match for entity: Rehabilitation
# No match for entity: Research Studies
# No match for entity: Clinical Trials
# No match for entity: Evidence-Based Medicine
# No match for entity: Guidelines
# No match for entity:
# Checking: (Strabismus <-> Amblyopia
#   Found relationships: ['REDUCES_RISK_OF']
# No
# Checking: (Strabismus <-> (Landolt C acuity
# Checking: (Strabismus <-> Snellen E acuity
# Checking: (Strabismus <-> (Vision Therapy
# Checking: (Strabismus <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (Strabismus <-> (Confounded psychological factors
# Checking: (Strabismus <-> (Orthoptics
# Checking: (Strabismus <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Strabismus <-> ARDS
# Checking: Amblyopia <-> (Strabismus
#   Found relationships: ['REDUCES_RISK_OF']
# No
# Checking: Amblyopia <-> (Landolt C acuity
# Checking: Amblyopia <-> Snellen E acuity
# Checking: Amblyopia <-> (Vision Therapy
#   Found relationships: ['TREATS', 'IS_COST_EFFECTIVE_FOR']
# Yes
# Yes
# Checking: Amblyopia <-> (Trivial impact on surgical management or neurological outcomes
# Checking: Amblyopia <-> (Confounded psychological factors
# Checking: Amblyopia <-> (Orthoptics
#   Found relationships: ['IS_USEFUL_FOR']
# Yes
# Checking: Amblyopia <-> (treatment outcomes in urothelial carcinoma patients
# Checking: Amblyopia <-> ARDS
# Checking: (Landolt C acuity <-> (Strabismus
# Checking: (Landolt C acuity <-> Amblyopia
# Checking: (Landolt C acuity <-> Snellen E acuity
#   Found relationships: ['IS_ASSOCIATED_WITH', 'IS_AS_EFFECTIVE_AS', 'IS_LESS_EFFECTIVE_THAN']
# Yes
# Yes
# No
# Checking: (Landolt C acuity <-> (Vision Therapy
# Checking: (Landolt C acuity <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (Landolt C acuity <-> (Confounded psychological factors
# Checking: (Landolt C acuity <-> (Orthoptics
# Checking: (Landolt C acuity <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Landolt C acuity <-> ARDS
# Checking: Snellen E acuity <-> (Strabismus
# Checking: Snellen E acuity <-> Amblyopia
# Checking: Snellen E acuity <-> (Landolt C acuity
#   Found relationships: ['IS_ASSOCIATED_WITH', 'IS_AS_EFFECTIVE_AS', 'IS_LESS_EFFECTIVE_THAN']
# Yes
# Yes
# No
# Checking: Snellen E acuity <-> (Vision Therapy
# Checking: Snellen E acuity <-> (Trivial impact on surgical management or neurological outcomes
# Checking: Snellen E acuity <-> (Confounded psychological factors
# Checking: Snellen E acuity <-> (Orthoptics
# Checking: Snellen E acuity <-> (treatment outcomes in urothelial carcinoma patients
# Checking: Snellen E acuity <-> ARDS
# Checking: (Vision Therapy <-> (Strabismus
# Checking: (Vision Therapy <-> Amblyopia
#   Found relationships: ['TREATS', 'IS_COST_EFFECTIVE_FOR']
# Yes
# Yes
# Checking: (Vision Therapy <-> (Landolt C acuity
# Checking: (Vision Therapy <-> Snellen E acuity
# Checking: (Vision Therapy <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (Vision Therapy <-> (Confounded psychological factors
# Checking: (Vision Therapy <-> (Orthoptics
# Checking: (Vision Therapy <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Vision Therapy <-> ARDS
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (Strabismus
# Checking: (Trivial impact on surgical management or neurological outcomes <-> Amblyopia
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (Landolt C acuity
# Checking: (Trivial impact on surgical management or neurological outcomes <-> Snellen E acuity
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (Vision Therapy
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (Confounded psychological factors
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (Orthoptics
# Checking: (Trivial impact on surgical management or neurological outcomes <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Trivial impact on surgical management or neurological outcomes <-> ARDS
# Checking: (Confounded psychological factors <-> (Strabismus
# Checking: (Confounded psychological factors <-> Amblyopia
# Checking: (Confounded psychological factors <-> (Landolt C acuity
# Checking: (Confounded psychological factors <-> Snellen E acuity
# Checking: (Confounded psychological factors <-> (Vision Therapy
# Checking: (Confounded psychological factors <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (Confounded psychological factors <-> (Orthoptics
# Checking: (Confounded psychological factors <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Confounded psychological factors <-> ARDS
# Checking: (Orthoptics <-> (Strabismus
# Checking: (Orthoptics <-> Amblyopia
#   Found relationships: ['IS_USEFUL_FOR']
# Yes
# Checking: (Orthoptics <-> (Landolt C acuity
# Checking: (Orthoptics <-> Snellen E acuity
# Checking: (Orthoptics <-> (Vision Therapy
# Checking: (Orthoptics <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (Orthoptics <-> (Confounded psychological factors
# Checking: (Orthoptics <-> (treatment outcomes in urothelial carcinoma patients
# Checking: (Orthoptics <-> ARDS
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Strabismus
# Checking: (treatment outcomes in urothelial carcinoma patients <-> Amblyopia
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Landolt C acuity
# Checking: (treatment outcomes in urothelial carcinoma patients <-> Snellen E acuity
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Vision Therapy
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Trivial impact on surgical management or neurological outcomes
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Confounded psychological factors
# Checking: (treatment outcomes in urothelial carcinoma patients <-> (Orthoptics
# Checking: (treatment outcomes in urothelial carcinoma patients <-> ARDS
# Checking: ARDS <-> (Strabismus
# Checking: ARDS <-> Amblyopia
# Checking: ARDS <-> (Landolt C acuity
# Checking: ARDS <-> Snellen E acuity
# Checking: ARDS <-> (Vision Therapy
# Checking: ARDS <-> (Trivial impact on surgical management or neurological outcomes
# Checking: ARDS <-> (Confounded psychological factors
# Checking: ARDS <-> (Orthoptics
# Checking: ARDS <-> (treatment outcomes in urothelial carcinoma patients
# Most common answer: Yes
# Processing question: Syncope during bathing in infants, a pediatric form of water-induced urticaria?
# START Syncope, Urticaria, Water-induced, Infants, Bathing, Pediatric, Form, Water-induced, Urticaria, Syncope, FINISHED
# ['Syncope', 'Urticaria', 'Water-induced', 'Infants', 'Bathing', 'Pediatric', 'Form', 'Water-induced', 'Urticaria', 'Syncope', '']
# No match for entity: Pediatric
# No match for entity:
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> (Infants discharged from an NICU
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> (prognostic information
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> Water-induced urticaria
# Checking: Aquagenic urticaria <-> (Infants discharged from an NICU
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> (prognostic information
# Checking: Aquagenic urticaria <-> Water-induced urticaria
# Checking: Aquagenic urticaria <-> Aquagenic urticaria
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> Aquagenic urticaria
# Checking: Water-induced urticaria <-> (Infants discharged from an NICU
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> (prognostic information
# Checking: Water-induced urticaria <-> Water-induced urticaria
# Checking: Water-induced urticaria <-> Aquagenic urticaria
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: (Infants discharged from an NICU <-> (Syncope during bathing in infants
# Checking: (Infants discharged from an NICU <-> Aquagenic urticaria
# Checking: (Infants discharged from an NICU <-> Water-induced urticaria
# Checking: (Infants discharged from an NICU <-> (Syncope during bathing in infants
# Checking: (Infants discharged from an NICU <-> (prognostic information
# Checking: (Infants discharged from an NICU <-> Water-induced urticaria
# Checking: (Infants discharged from an NICU <-> Aquagenic urticaria
# Checking: (Infants discharged from an NICU <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> (Infants discharged from an NICU
# Checking: (Syncope during bathing in infants <-> (prognostic information
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: (prognostic information <-> (Syncope during bathing in infants
# Checking: (prognostic information <-> Aquagenic urticaria
# Checking: (prognostic information <-> Water-induced urticaria
# Checking: (prognostic information <-> (Infants discharged from an NICU
# Checking: (prognostic information <-> (Syncope during bathing in infants
# Checking: (prognostic information <-> Water-induced urticaria
# Checking: (prognostic information <-> Aquagenic urticaria
# Checking: (prognostic information <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> Aquagenic urticaria
# Checking: Water-induced urticaria <-> Water-induced urticaria
# Checking: Water-induced urticaria <-> (Infants discharged from an NICU
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: Water-induced urticaria <-> (prognostic information
# Checking: Water-induced urticaria <-> Aquagenic urticaria
# Checking: Water-induced urticaria <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> Aquagenic urticaria
# Checking: Aquagenic urticaria <-> Water-induced urticaria
# Checking: Aquagenic urticaria <-> (Infants discharged from an NICU
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: Aquagenic urticaria <-> (prognostic information
# Checking: Aquagenic urticaria <-> Water-induced urticaria
# Checking: Aquagenic urticaria <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> (Infants discharged from an NICU
# Checking: (Syncope during bathing in infants <-> (Syncope during bathing in infants
# Checking: (Syncope during bathing in infants <-> (prognostic information
# Checking: (Syncope during bathing in infants <-> Water-induced urticaria
# Checking: (Syncope during bathing in infants <-> Aquagenic urticaria
# ...
#   Found relationships: ['IS_ASSOCIATED_WITH', 'DOES_NOT_CAUSE']
# Yes
# No
# Most common answer: Yes
# Processing question: Transgastric endoscopic splenectomy: is it possible?
# START Transgastric Endoscopic Splenectomy Procedure, Endoscopy, Splenectomy, Surgery, Medicine, FINISHED
# ['Transgastric Endoscopic Splenectomy Procedure', 'Endoscopy', 'Splenectomy', 'Surgery', 'Medicine', '']
# No match for entity:
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> (Complications of Open Surgery
# Checking: Transgastric Endoscopic Splenectomy <-> Emergency Medicine Residents
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> (Complications of Open Surgery
# Checking: Transgastric Endoscopic Splenectomy <-> Emergency Medicine Residents
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> Transgastric Endoscopic Splenectomy
# Checking: Transgastric Endoscopic Splenectomy <-> (Complications of Open Surgery
# Checking: Transgastric Endoscopic Splenectomy <-> Emergency Medicine Residents
# Checking: (Complications of Open Surgery <-> Transgastric Endoscopic Splenectomy
# Checking: (Complications of Open Surgery <-> Transgastric Endoscopic Splenectomy
# Checking: (Complications of Open Surgery <-> Transgastric Endoscopic Splenectomy
# Checking: (Complications of Open Surgery <-> Emergency Medicine Residents
# Checking: Emergency Medicine Residents <-> Transgastric Endoscopic Splenectomy
# Checking: Emergency Medicine Residents <-> Transgastric Endoscopic Splenectomy
# Checking: Emergency Medicine Residents <-> Transgastric Endoscopic Splenectomy
# Checking: Emergency Medicine Residents <-> (Complications of Open Surgery
# No definitive relationship found.
# Processing question: It's Fournier's gangrene still dangerous?
# START Fournier's gangrene, Gangrene, Infection, Complications, Danger, Risk, Mortality, Healthcare, Treatment, Medicine, FINISHED
# ["Fournier's gangrene", 'Gangrene', 'Infection', 'Complications', 'Danger', 'Risk', 'Mortality', 'Healthcare', 'Treatment', 'Medicine', '']
# No match for entity: Danger
# No match for entity:
# Checking: Fourniers gangrene <-> Fourniers gangrene
# Checking: Fourniers gangrene <-> (Infection and Bleeding
# Checking: Fourniers gangrene <-> (Complications of Open Surgery
# Checking: Fourniers gangrene <-> (Increased risk of vaccine-preventable diseases
# Checking: Fourniers gangrene <-> (overall mortality
# Checking: Fourniers gangrene <-> (Healthcare providers advice
# Checking: Fourniers gangrene <-> Immediate medical treatment
# Checking: Fourniers gangrene <-> Emergency Medicine Residents
# Checking: Fourniers gangrene <-> Fourniers gangrene
# Checking: Fourniers gangrene <-> (Infection and Bleeding
# Checking: Fourniers gangrene <-> (Complications of Open Surgery
# Checking: Fourniers gangrene <-> (Increased risk of vaccine-preventable diseases
# Checking: Fourniers gangrene <-> (overall mortality
# Checking: Fourniers gangrene <-> (Healthcare providers advice
# Checking: Fourniers gangrene <-> Immediate medical treatment
# Checking: Fourniers gangrene <-> Emergency Medicine Residents
# Checking: (Infection and Bleeding <-> Fourniers gangrene
# Checking: (Infection and Bleeding <-> Fourniers gangrene
# Checking: (Infection and Bleeding <-> (Complications of Open Surgery
# Checking: (Infection and Bleeding <-> (Increased risk of vaccine-preventable diseases
# Checking: (Infection and Bleeding <-> (overall mortality
# Checking: (Infection and Bleeding <-> (Healthcare providers advice
# Checking: (Infection and Bleeding <-> Immediate medical treatment
# Checking: (Infection and Bleeding <-> Emergency Medicine Residents
# Checking: (Complications of Open Surgery <-> Fourniers gangrene
# Checking: (Complications of Open Surgery <-> Fourniers gangrene
# Checking: (Complications of Open Surgery <-> (Infection and Bleeding
# Checking: (Complications of Open Surgery <-> (Increased risk of vaccine-preventable diseases
# Checking: (Complications of Open Surgery <-> (overall mortality
# Checking: (Complications of Open Surgery <-> (Healthcare providers advice
# Checking: (Complications of Open Surgery <-> Immediate medical treatment
# Checking: (Complications of Open Surgery <-> Emergency Medicine Residents
# Checking: (Increased risk of vaccine-preventable diseases <-> Fourniers gangrene
# Checking: (Increased risk of vaccine-preventable diseases <-> Fourniers gangrene
# Checking: (Increased risk of vaccine-preventable diseases <-> (Infection and Bleeding
# Checking: (Increased risk of vaccine-preventable diseases <-> (Complications of Open Surgery
# Checking: (Increased risk of vaccine-preventable diseases <-> (overall mortality
# Checking: (Increased risk of vaccine-preventable diseases <-> (Healthcare providers advice
# Checking: (Increased risk of vaccine-preventable diseases <-> Immediate medical treatment
# Checking: (Increased risk of vaccine-preventable diseases <-> Emergency Medicine Residents
# Checking: (overall mortality <-> Fourniers gangrene
# Checking: (overall mortality <-> Fourniers gangrene
# Checking: (overall mortality <-> (Infection and Bleeding
# Checking: (overall mortality <-> (Complications of Open Surgery
# Checking: (overall mortality <-> (Increased risk of vaccine-preventable diseases
# Checking: (overall mortality <-> (Healthcare providers advice
# Checking: (overall mortality <-> Immediate medical treatment
# Checking: (overall mortality <-> Emergency Medicine Residents
# Checking: (Healthcare providers advice <-> Fourniers gangrene
# Checking: (Healthcare providers advice <-> Fourniers gangrene
# Checking: (Healthcare providers advice <-> (Infection and Bleeding
# Checking: (Healthcare providers advice <-> (Complications of Open Surgery
# Checking: (Healthcare providers advice <-> (Increased risk of vaccine-preventable diseases
# Checking: (Healthcare providers advice <-> (overall mortality
# Checking: (Healthcare providers advice <-> Immediate medical treatment
# Checking: (Healthcare providers advice <-> Emergency Medicine Residents
# Checking: Immediate medical treatment <-> Fourniers gangrene
# Checking: Immediate medical treatment <-> Fourniers gangrene
# Checking: Immediate medical treatment <-> (Infection and Bleeding
# Checking: Immediate medical treatment <-> (Complications of Open Surgery
# Checking: Immediate medical treatment <-> (Increased risk of vaccine-preventable diseases
# Checking: Immediate medical treatment <-> (overall mortality
# Checking: Immediate medical treatment <-> (Healthcare providers advice
# Checking: Immediate medical treatment <-> Emergency Medicine Residents
# Checking: Emergency Medicine Residents <-> Fourniers gangrene
# Checking: Emergency Medicine Residents <-> Fourniers gangrene
# Checking: Emergency Medicine Residents <-> (Infection and Bleeding
# Checking: Emergency Medicine Residents <-> (Complications of Open Surgery
# Checking: Emergency Medicine Residents <-> (Increased risk of vaccine-preventable diseases
# Checking: Emergency Medicine Residents <-> (overall mortality
# Checking: Emergency Medicine Residents <-> (Healthcare providers advice
# Checking: Emergency Medicine Residents <-> Immediate medical treatment
# No definitive relationship found.
# Processing question: Is it appropriate to implant kidneys from elderly donors in young recipients?
# START Organ Transplantation, Kidney Donation, Elderly Donors, Young Recipients, Implantation, Medical Ethics, Organ Allocation, Healthcare Policy, Bioethics, Patient Autonomy, Quality of Life, Health Outcomes, Risk-Benefit Analysis, Social Justice, Human Rights FINISHED
# ['Organ Transplantation', 'Kidney Donation', 'Elderly Donors', 'Young Recipients', 'Implantation', 'Medical Ethics', 'Organ Allocation', 'Healthcare Policy', 'Bioethics', 'Patient Autonomy', 'Quality of Life', 'Health Outcomes', 'Risk-Benefit Analysis', 'Social Justice', 'Human Rights']
# No match for entity: Kidney Donation
# No match for entity: Medical Ethics
# No match for entity: Organ Allocation
# No match for entity: Bioethics
# No match for entity: Patient Autonomy
# No match for entity: Risk-Benefit Analysis
# No match for entity: Social Justice
# No match for entity: Human Rights
# Checking: Cadaveric liver transplantation <-> Elderly donors
# Checking: Cadaveric liver transplantation <-> Young recipients
# Checking: Cadaveric liver transplantation <-> Implantation of kidneys
# Checking: Cadaveric liver transplantation <-> (Healthcare providers advice
# Checking: Cadaveric liver transplantation <-> (quality of life in lace plant
# Checking: Cadaveric liver transplantation <-> (Infant health outcomes
# Checking: Elderly donors <-> Cadaveric liver transplantation
# Checking: Elderly donors <-> Young recipients
# Checking: Elderly donors <-> Implantation of kidneys
# Checking: Elderly donors <-> (Healthcare providers advice
# Checking: Elderly donors <-> (quality of life in lace plant
# Checking: Elderly donors <-> (Infant health outcomes
# Checking: Young recipients <-> Cadaveric liver transplantation
# Checking: Young recipients <-> Elderly donors
# Checking: Young recipients <-> Implantation of kidneys
# Checking: Young recipients <-> (Healthcare providers advice
# Checking: Young recipients <-> (quality of life in lace plant
# Checking: Young recipients <-> (Infant health outcomes
# Checking: Implantation of kidneys <-> Cadaveric liver transplantation
# Checking: Implantation of kidneys <-> Elderly donors
# Checking: Implantation of kidneys <-> Young recipients
# Checking: Implantation of kidneys <-> (Healthcare providers advice
# Checking: Implantation of kidneys <-> (quality of life in lace plant
# Checking: Implantation of kidneys <-> (Infant health outcomes
# Checking: (Healthcare providers advice <-> Cadaveric liver transplantation
# Checking: (Healthcare providers advice <-> Elderly donors
# Checking: (Healthcare providers advice <-> Young recipients
# Checking: (Healthcare providers advice <-> Implantation of kidneys
# Checking: (Healthcare providers advice <-> (quality of life in lace plant
# Checking: (Healthcare providers advice <-> (Infant health outcomes
# Checking: (quality of life in lace plant <-> Cadaveric liver transplantation
# Checking: (quality of life in lace plant <-> Elderly donors
# Checking: (quality of life in lace plant <-> Young recipients
# Checking: (quality of life in lace plant <-> Implantation of kidneys
# Checking: (quality of life in lace plant <-> (Healthcare providers advice
# Checking: (quality of life in lace plant <-> (Infant health outcomes
# Checking: (Infant health outcomes <-> Cadaveric liver transplantation
# Checking: (Infant health outcomes <-> Elderly donors
# Checking: (Infant health outcomes <-> Young recipients
# Checking: (Infant health outcomes <-> Implantation of kidneys
# Checking: (Infant health outcomes <-> (Healthcare providers advice
# Checking: (Infant health outcomes <-> (quality of life in lace plant
# No definitive relationship found.
# Processing question: Do provider service networks result in lower expenditures compared with HMOs or primary care case management in Florida's Medicaid program?
# START Provider Service Networks, Medicaid Program, Florida, HMOs, Primary Care Case Management, Expenditures, Medicaid Expenditure Rates, Managed Care Organizations, Health Maintenance Organizations, Cost Containment Strategies, Healthcare Expenditure Analysis, State-Specific Comparative Effectiveness Research, Medicaid Spending Patterns, Network Effects, Care Coordination Models, Population-Based Payment Systems, Value-Based Care Initiatives, Cost-Benefit Analysis FINISHED
# ['Provider Service Networks', 'Medicaid Program', 'Florida', 'HMOs', 'Primary Care Case Management', 'Expenditures', 'Medicaid Expenditure Rates', 'Managed Care Organizations', 'Health Maintenance Organizations', 'Cost Containment Strategies', 'Healthcare Expenditure Analysis', 'State-Specific Comparative Effectiveness Research', 'Medicaid Spending Patterns', 'Network Effects', 'Care Coordination Models', 'Population-Based Payment Systems', 'Value-Based Care Initiatives', 'Cost-Benefit Analysis']
# No match for entity: Primary Care Case Management
# No match for entity: Medicaid Expenditure Rates
# No match for entity: Managed Care Organizations
# No match for entity: Health Maintenance Organizations
# No match for entity: Cost Containment Strategies
# No match for entity: Healthcare Expenditure Analysis
# No match for entity: State-Specific Comparative Effectiveness Research
# No match for entity: Medicaid Spending Patterns
# No match for entity: Network Effects
# No match for entity: Care Coordination Models
# No match for entity: Population-Based Payment Systems
# No match for entity: Value-Based Care Initiatives
# No match for entity: Cost-Benefit Analysis
# Checking: (Provider Service Networks <-> (Floridas Medicaid program
# Checking: (Provider Service Networks <-> (Floridas Medicaid program
# Checking: (Provider Service Networks <-> Demonstration HMOs
# Checking: (Provider Service Networks <-> Payment Expenditures
#   Found relationships: ['REDUCES_RISK_OF']
# No
# Checking: (Floridas Medicaid program <-> (Provider Service Networks
# Checking: (Floridas Medicaid program <-> (Floridas Medicaid program
# Checking: (Floridas Medicaid program <-> Demonstration HMOs
# Checking: (Floridas Medicaid program <-> Payment Expenditures
#   Found relationships: ['IS_COST_EFFECTIVE_FOR', 'IS_USEFUL_FOR']
# Yes
# Yes
# Checking: (Floridas Medicaid program <-> (Provider Service Networks
# Checking: (Floridas Medicaid program <-> (Floridas Medicaid program
# Checking: (Floridas Medicaid program <-> Demonstration HMOs
# Checking: (Floridas Medicaid program <-> Payment Expenditures
#   Found relationships: ['IS_COST_EFFECTIVE_FOR', 'IS_USEFUL_FOR']
# Yes
# Yes
# Checking: Demonstration HMOs <-> (Provider Service Networks
# Checking: Demonstration HMOs <-> (Floridas Medicaid program
# Checking: Demonstration HMOs <-> (Floridas Medicaid program
# Checking: Demonstration HMOs <-> Payment Expenditures
# Checking: Payment Expenditures <-> (Provider Service Networks
#   Found relationships: ['REDUCES_RISK_OF']
# No
# Checking: Payment Expenditures <-> (Floridas Medicaid program
#   Found relationships: ['IS_COST_EFFECTIVE_FOR', 'IS_USEFUL_FOR']
# Yes
# Yes
# Checking: Payment Expenditures <-> (Floridas Medicaid program
#   Found relationships: ['IS_COST_EFFECTIVE_FOR', 'IS_USEFUL_FOR']
# Yes
# Yes
# Checking: Payment Expenditures <-> Demonstration HMOs
# Most common answer: Yes
# Processing question: Assessment of carotid artery stenosis before coronary artery bypass surgery. Is it always necessary?
# START Carotid Artery Stenosis Assessment, Coronary Artery Bypass Surgery, Carotid Artery Disease, Atherosclerosis, Angiography, Non-Invasive Testing, Imaging Modalities, Cardiac Risk Stratification, Surgical Planning, Preoperative Evaluation, Anatomical Considerations, Patient Selection Criteria, FINISHED
# ['Carotid Artery Stenosis Assessment', 'Coronary Artery Bypass Surgery', 'Carotid Artery Disease', 'Atherosclerosis', 'Angiography', 'Non-Invasive Testing', 'Imaging Modalities', 'Cardiac Risk Stratification', 'Surgical Planning', 'Preoperative Evaluation', 'Anatomical Considerations', 'Patient Selection Criteria', '']
# No match for entity: Carotid Artery Disease
# No match for entity: Angiography
# No match for entity: Non-Invasive Testing
# No match for entity: Imaging Modalities
# No match for entity: Cardiac Risk Stratification
# No match for entity: Surgical Planning
# No match for entity: Preoperative Evaluation
# No match for entity: Anatomical Considerations
# No match for entity: Patient Selection Criteria
# No match for entity:
# Checking: Carotid artery stenosis <-> Surgery
# Checking: Carotid artery stenosis <-> (atherosclerosis
# Checking: Surgery <-> Carotid artery stenosis
# Checking: Surgery <-> (atherosclerosis
# Checking: (atherosclerosis <-> Carotid artery stenosis
# Checking: (atherosclerosis <-> Surgery
# No definitive relationship found.

# %% [markdown]
# # Compute Accuracy

# %%
correct_count = sum([1 for model, correct in zip(generated_answers, answer_key) if model.lower() == correct])

print(f"Correct answers: {correct_count}/{len(generated_answers)}")
print()

# Print answers side by side
for i, (model_answer, correct_answer) in enumerate(zip(generated_answers, answer_key), 1):
    print(f"Q{i}: Our Answer: {model_answer.lower()}\tAnswer Key: {correct_answer}")
# Out:
# Correct answers: 23/50
#
# Q1: Our Answer: yes	Answer Key: yes
# Q2: Our Answer: yes	Answer Key: no
# Q3: Our Answer: maybe	Answer Key: yes
# Q4: Our Answer: no	Answer Key: no
# Q5: Our Answer: maybe	Answer Key: yes
# Q6: Our Answer: maybe	Answer Key: yes
# Q7: Our Answer: no	Answer Key: maybe
# Q8: Our Answer: maybe	Answer Key: no
# Q9: Our Answer: no	Answer Key: no
# Q10: Our Answer: yes	Answer Key: yes
# Q11: Our Answer: yes	Answer Key: yes
# Q12: Our Answer: yes	Answer Key: no
# Q13: Our Answer: maybe	Answer Key: yes
# Q14: Our Answer: yes	Answer Key: no
# Q15: Our Answer: yes	Answer Key: yes
# Q16: Our Answer: yes	Answer Key: yes
# Q17: Our Answer: maybe	Answer Key: yes
# Q18: Our Answer: no	Answer Key: yes
# Q19: Our Answer: yes	Answer Key: yes
# Q20: Our Answer: yes	Answer Key: yes
# Q21: Our Answer: maybe	Answer Key: yes
# Q22: Our Answer: no	Answer Key: yes
# Q23: Our Answer: yes	Answer Key: yes
# Q24: Our Answer: maybe	Answer Key: yes
# Q25: Our Answer: yes	Answer Key: yes
# Q26: Our Answer: yes	Answer Key: no
# Q27: Our Answer: yes	Answer Key: yes
# Q28: Our Answer: no	Answer Key: maybe
# Q29: Our Answer: yes	Answer Key: yes
# Q30: Our Answer: yes	Answer Key: yes
# Q31: Our Answer: no	Answer Key: no
# Q32: Our Answer: maybe	Answer Key: maybe
# Q33: Our Answer: maybe	Answer Key: no
# Q34: Our Answer: maybe	Answer Key: yes
# Q35: Our Answer: yes	Answer Key: yes
# Q36: Our Answer: maybe	Answer Key: no
# Q37: Our Answer: yes	Answer Key: no
# Q38: Our Answer: yes	Answer Key: no
# Q39: Our Answer: yes	Answer Key: yes
# Q40: Our Answer: yes	Answer Key: no
# Q41: Our Answer: yes	Answer Key: yes
# Q42: Our Answer: yes	Answer Key: yes
# Q43: Our Answer: maybe	Answer Key: maybe
# Q44: Our Answer: yes	Answer Key: no
# Q45: Our Answer: yes	Answer Key: yes
# Q46: Our Answer: maybe	Answer Key: yes
# Q47: Our Answer: maybe	Answer Key: yes
# Q48: Our Answer: maybe	Answer Key: yes
# Q49: Our Answer: yes	Answer Key: yes
# Q50: Our Answer: maybe	Answer Key: no
