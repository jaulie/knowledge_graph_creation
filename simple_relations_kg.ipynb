# %% [markdown]
# # Knowledge Graph Creation

# %%
import json
import re
import getpass
import os
from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI
from neo4j import GraphDatabase

# %% [markdown]
# ### This is where we alter the prompt for our experiment.
# #### These are currently extremely simplified and logically not very sound (in terms of medical question answering but fine for just finding relations)
# #### If the kg syntax errors it's because I haven't implemented strict output types yet

# %%
# Queries a LLM to extract entities only
def entities_query(text: str):
     return f'''Please return a list of all single and multi-word terms and phrases from the following text that could describe a term, entity, or idea: {text}.
       Ignore stop words like and, but, or, with, and other words like that.
       If a set of words combined describe one specific thing, please return it as one item in the list. 
       For example, in the example sentence "The auxiliary medical device effects the blood pressure of the patient", the list would look like [auxiliary medical device, medical device, device, blood pressure of the patient, blood pressure]. 
       Another example, in the example input "Do radiologists tend to perform better under cooler temperatures?", the list would look like [radiologists, cooler, cooler temperatures, temperatures].
       If an item in the list contains adjectives describing a noun, please make sure that noun is included on its own in the list as well. 
       Now please respond with absolutely nothing except the list of any and all single and multi-word terms and phrases from the following text that could describe a term, entity, or idea: {text}.'''

# Returns a query to a LLM that includes a text sample and a list of entities. The query instructs the LLM to return a set of triples with relations. 
# The possible relations are: POS, NEG, MAY
def kg_query(entities: list[str], sample: str):
    return f'''Here is a text sample with information about a medical topic: {sample}.
    Here is a list of entities pulled from that list: {entities}.
    For each entity in the list above (entity1), find every single other entities (entity2) that it is related to in any way from the list based on the text sample.
    If that relationship could be described as neutral to positive (or synonymous with positive given the context), please return that relationship as follows: [entity1, POS, entity2]
    If that relationship could be described as less than neutral to negative (or synonymous with negative given the context), please return that relationship as follows: term1 = entity1, relation = [entity1, NEG, entity2]
    If and only if that relationship is stated to be unknown or unsure with proper descriptors to match, only then return that relationship as follows: [entity1, MAY, entity2]
    Return all of these possible permutations as a list of string relationships in the format described above. 
    Do not respond with anything except that list in the following format, and make sure syntax is exact (do not add newline characters):
    [(entity1, relation, entity2), ... ]
    '''

# %% [markdown]
# #### Extra function definition

# %%
def convert_to_tuples(input_list):
    result = []
    
    for item in input_list:
        # Remove unnecessary characters and parse the string representation of a list of tuples
        item_clean = item.strip('[]').replace('\n', '')  # Remove square brackets and newlines
        tuples = re.findall(r'\(([^)]+)\)', item_clean)  # Match content inside parentheses
        for t in tuples:
            # Convert each tuple string into a tuple of terms (term, relation, term)
            term1, relation, term2 = [x.strip() for x in t.split(',')]
            result.append((term1, relation, term2))
    
    return result

# %% [markdown]
# ### Read in json file

# %%
# Global variable, set to the number of abstracts to be read in
# Set to -1 to read in all abstracts
NUM = 50

# %%
filename = "../ori_pqal.json"
with open(filename, 'r', encoding='utf-8') as f:
    labeled_instances = json.load(f)

#get questions and long answers 
# IMPORTANT: THIS ASSUMES THAT EACH ENTRY IN THE JSON FILE HAS A QUESTION, CONCLUSION, GROUND TRUTH IN THIS FORMAT. 
# IF WE FIND BAD RESULTS IN LATER QUESTIONS LOOK HERE
questions = []
conclusions = []
ground_truth = []
print(labeled_instances[0])
for paper in labeled_instances:
    questions.append(labeled_instances[paper]['QUESTION'])
    conclusions.append(labeled_instances[paper]['LONG_ANSWER'])
    ground_truth.append(labeled_instances[paper]['final_decision'])
    
#Only use first 5 for now
questions = questions[:NUM]
titles = questions[:NUM]
conclusions = conclusions[:NUM]
ground_truth = ground_truth[:NUM]

# %% [markdown]
# ### Set LLM as desired model

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0, max_tokens=None) 
#llm = ChatOllama(model="llama3.2")

# %% [markdown]
# ## Querying LLM to create KG
#
# #### First, query LLM to extract relevant entities from each conclusion, then query LLM with entities and conclusion to create KG

# %%
kg = []
for idx in range(len(conclusions)):
    # Use query defined above to extract entities from conclusion
    sentence_output = llm.invoke(entities_query(titles[idx])).content.replace("'", "")
    # Regex in place of strict relation types
    entities = [re.sub(r'[^a-zA-Z0-9]', '', re.sub(r'^\d+\.\s*', '', item)) for item in sentence_output.split("\n")]
    # Create KG using those entities and query defined above
    kg.append(llm.invoke(kg_query(entities, conclusions[idx])).content)

# Fix formatting of list (function defined above)
print(kg)
knowledge_graph = convert_to_tuples(kg)
# Out:
# ['[(mitochondriaroleremodellinglaceplantleaveslaceplantplantleavesleavesprogrammedcelldeathcelldeathdeath, POS, mitochondriaroleremodellinglaceplantleaveslaceplantplantleavesleavesprogrammedcelldeathcelldeathdeath)]', "[('SnellenE', POS, 'LandoltC'), ('SnellenE', POS, 'SnellenEacuity'), ('SnellenE', POS, 'acuity'), ('SnellenE', POS, 'strabismusamblyopia'), ('SnellenE', POS, 'strabismus'), ('SnellenE', POS, 'amblyopia'), ('LandoltC', POS, 'SnellenEacuity'), ('LandoltC', POS, 'acuity'), ('LandoltC', POS, 'strabismusamblyopia'), ('LandoltC', POS, 'strabismus'), ('LandoltC', POS, 'amblyopia'), ('SnellenEacuity', POS, 'acuity'), ('SnellenEacuity', POS, 'strabismusamblyopia'), ('SnellenEacuity', POS, 'strabismus'), ('SnellenEacuity', POS, 'amblyopia'), ('acuity', POS, 'strabismusamblyopia'), ('acuity', POS, 'strabismus'), ('acuity', POS, 'amblyopia'), ('differences', NEG, 'SnellenEacuity'), ('differences', NEG, 'acuity')]", "[('Syncopeduringbathingininfants', MAY, 'Pediatricformofwaterinducedurticaria'), ('Syncopeduringbathingininfants', MAY, 'Pediatricform'), ('Syncopeduringbathingininfants', MAY, 'Waterinducedurticaria'), ('Syncopeduringbathingininfants', MAY, 'Urticaria'), ('Syncope', MAY, 'Pediatricformofwaterinducedurticaria'), ('Syncope', MAY, 'Pediatricform'), ('Syncope', MAY, 'Waterinducedurticaria'), ('Syncope', MAY, 'Urticaria'), ('Bathingininfants', MAY, 'Pediatricformofwaterinducedurticaria'), ('Bathingininfants', MAY, 'Pediatricform'), ('Bathingininfants', MAY, 'Waterinducedurticaria'), ('Bathingininfants', MAY, 'Urticaria'), ('Bathing', MAY, 'Pediatricformofwaterinducedurticaria'), ('Bathing', MAY, 'Pediatricform'), ('Bathing', MAY, 'Waterinducedurticaria'), ('Bathing', MAY, 'Urticaria'), ('Infants', MAY, 'Pediatricformofwaterinducedurticaria'), ('Infants', MAY, 'Pediatricform'), ('Infants', MAY, 'Waterinducedurticaria'), ('Infants', MAY, 'Urticaria'), ('Pediatricformofwaterinducedurticaria', POS, 'Pediatricform'), ('Pediatricformofwaterinducedurticaria', POS, 'Waterinducedurticaria'), ('Pediatricformofwaterinducedurticaria', POS, 'Urticaria'), ('Pediatricform', POS, 'Waterinducedurticaria'), ('Pediatricform', POS, 'Urticaria'), ('Waterinducedurticaria', POS, 'Urticaria')]", "[('longtermresultsresultstransanalpullthroughtransanalpullthroughtransabdominalpullthroughtransabdominal', POS, 'longtermresultsresultstransanalpullthroughtransanalpullthroughtransabdominalpullthroughtransabdominal')]", '[(taioredinterventionsinterventionsmammographyusemammographyHMOwomenwomen, NEG, taioredinterventionsinterventionsmammographyusemammographyHMOwomenwomen)]', "[('Doubleballoonenteroscopyballoonenteroscopyenteroscopycommunitysettingsetting', POS, 'Doubleballoonenteroscopyballoonenteroscopyenteroscopycommunitysettingsetting')]", '[]', '[]', '[]', "[('shortstay23hourwardwardgeneralandacademicchildrenshospitalgeneralchildrenshospitalacademicchildrenshospitalchildrenshospitalhospital', 'POS', 'bed efficient'), ('shortstay23hourwardwardgeneralandacademicchildrenshospitalgeneralchildrenshospitalacademicchildrenshospitalchildrenshospitalhospital', 'POS', 'patient care'), ('shortstay23hourwardwardgeneralandacademicchildrenshospitalgeneralchildrenshospitalacademicchildrenshospitalchildrenshospitalhospital', 'POS', 'parental satisfaction'), ('shortstay23hourwardwardgeneralandacademicchildrenshospitalgeneralchildrenshospitalacademicchildrenshospitalchildrenshospitalhospital', 'POS', 'early return of the child with their family to the community')]", "[('Chilestrafficlawreform', POS, 'trafficlawreform'), ('trafficlawreform', POS, 'lawreform'), ('lawreform', POS, 'reform'), ('reform', POS, 'policeenforcement'), ('policeenforcement', POS, 'enforcement')]", "[('Therapeuticanticoagulationanticoagulationtraumapatientpatient', MAY, 'Therapeuticanticoagulationanticoagulationtraumapatientpatient')]", "[('Differentiation', NEG, 'Nonalcoholicsteatohepatitis'), ('Differentiation', NEG, 'Alcoholicsteatohepatitis')]", '[]', "[('emergencyultrasoundfellowshippr ...

# %% [markdown]
# ## Neo4j setup

# %%
uri = "bolt://localhost:7687"
username = "neo4j"
password = "neo4j_password"

# %% [markdown]
# ### Neo4j Knowledge Graph Creation

# %%
driver = GraphDatabase.driver(uri, auth=(username, password))

### Knowledge Graph Creation

def create_knowledge_graph(data):
    '''
    Creates a Neo4jGraph with the relations populated in it
    '''
    with driver.session() as session:
        for node1, relation, node2 in data:
            session.execute_write(create_relationship, node1.capitalize(), relation, node2.capitalize())


def create_relationship(tx, node1, relation, node2):
    '''
    Creates a relation
    '''
    relation_map = {
        "POS": "positively_related_to",
        "NEG": "negatively_related_to",
        "MAY": "may_be_related_to"
    }
    
    relationship = relation_map.get(relation, "related_to") 

    query = (
        "MERGE (a:Entity {name: $node1}) "
        "MERGE (b:Entity {name: $node2}) "
        "MERGE (a)-[r:" + relationship + "]->(b)"
    )
    tx.run(query, node1=node1, relation=relationship, node2=node2)

create_knowledge_graph(knowledge_graph)

# Close the driver connection after use

# %% [markdown]
# #### Take a peek in the knowledge graph

# %%
'''
def query_graph():
    # Open a session with the Neo4j database
    with driver.session() as session:
        # Run the query to get the first 25 nodes and their relationships
        result = session.run("""
            MATCH (n)-[r]->(m) 
            RETURN n, r, m 
            LIMIT 25
        """)
        
        # Iterate through the result and print the nodes and relationships
        for record in result:
            node1 = record['n']
            relation = record['r']
            node2 = record['m']
            
            print({
                'Node1': node1['name'],  # Assuming 'name' is a property
                'Relation': type(relation).__name__,  # Type of the relationship
                'Node2': node2['name']  # Assuming 'name' is a property
            })
    session.close()

query_graph()

'''
# Out:
# '\ndef query_graph():\n    # Open a session with the Neo4j database\n    with driver.session() as session:\n        # Run the query to get the first 25 nodes and their relationships\n        result = session.run("""\n            MATCH (n)-[r]->(m) \n            RETURN n, r, m \n            LIMIT 25\n        """)\n        \n        # Iterate through the result and print the nodes and relationships\n        for record in result:\n            node1 = record[\'n\']\n            relation = record[\'r\']\n            node2 = record[\'m\']\n            \n            print({\n                \'Node1\': node1[\'name\'],  # Assuming \'name\' is a property\n                \'Relation\': type(relation).__name__,  # Type of the relationship\n                \'Node2\': node2[\'name\']  # Assuming \'name\' is a property\n            })\n    session.close()\n\nquery_graph()\n\n'

# %% [markdown]
# ### Question evaluation (will change with relation type)

# %%
with driver.session() as session:
    truth_index = -1
    numerator = 0
    not_found = 0
    for question in questions:
        truth_index = truth_index + 1
        response = "no answer found"
        question_output = llm.invoke(entities_query(question)).content.replace("'", "")
        ##nodes = [re.sub(r'[^a-zA-Z0-9]', '', re.sub(r'^\d+\.\s*', '', item)) for item in question_output.split("\n")]
        nodes = question_output.split(",")
        nodes = [re.sub(r'\s+', '', s) for s in nodes]
        print("Question nodes:", nodes)
        for i in range(len(nodes)):
            for j in range(i+1, len(nodes)): 
                cypher_query = f"""
                            MATCH (n {{name: '{nodes[i].capitalize()}'}})-[r]->(m {{name: '{nodes[j].capitalize()}'}})
                            RETURN n, r, m
                        """
                result = session.run(cypher_query)
                
                if result.peek():
                    # Logic based on current relation types
                    for record in result:
                        if record['r'].type == 'negatively_related_to':
                            response = 'no'
                        elif record['r'].type == 'positively_related_to':
                            response = 'yes'
                        else: 
                            response = 'maybe'                        
                    break 
        print(truth_index)
        print('Question:', question, '\nResponse:', response, '\nGround Truth:', ground_truth[truth_index], '\n\n')
        if response == ground_truth[truth_index]:
            numerator += 1
        if response == "no answer found":
            not_found += 1
    print('Accuracy:', numerator / len(questions))
    print('Not found rate:', not_found / len(questions))
driver.close()
# Out:
# /var/folders/dm/x6rq680x18s59pvdfd0bkv_80000gn/T/ipykernel_1021/2576860419.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# Question nodes: ['mitochondria', 'role', 'remodelling', 'laceplantleaves', 'programmedcelldeath']
# 0
# Question: Do mitochondria play a role in remodelling lace plant leaves during programmed cell death?
# Response: yes
# Ground Truth: yes
#
#
# Question nodes: ['[LandoltC', 'SnellenEacuity', 'differences', 'strabismus', 'amblyopia]']
# 1
# Question: Landolt C and snellen e acuity: differences in strabismus amblyopia?
# Response: maybe
# Ground Truth: no
#
#
# Question nodes: ['[Syncopeduringbathing', 'infants', 'pediatricform', 'water-inducedurticaria]']
# 2
# Question: Syncope during bathing in infants, a pediatric form of water-induced urticaria?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[long-termresults', 'transanalpull-through', 'transabdominalpull-through]']
# 3
# Question: Are the long-term results of the transanal pull-through equal to those of the transabdominal pull-through?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['tailoredinterventions', 'increasemammographyuse', 'HMOwomen', 'mammographyuse', 'HMO']
# 4
# Question: Can tailored interventions increase mammography use among HMO women?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Doubleballoonenteroscopy', 'efficacious', 'safe', 'communitysetting]']
# 5
# Question: Double balloon enteroscopy: is it efficacious and safe in a community setting?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['30-Daymortality', '1-yearmortality', 'emergencygeneralsurgery', 'laparotomies', 'areaofconcern', 'needforimprovement']
# 6
# Question: 30-Day and 1-year mortality in emergency general surgery laparotomies: an area of concern and need for improvement?
# Response: maybe
# Ground Truth: maybe
#
#
# Question nodes: ['[adjustment', 'reportingheterogeneity', 'sleepdisorders]']
# 7
# Question: Is adjustment for reporting heterogeneity necessary in sleep disorders?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['mutations', 'lowHDL-C', 'increasedcarotidintima-mediathickness']
# 8
# Question: Do mutations causing low HDL-C promote increased carotid intima-media thickness?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['[shortstay', '23-hourward', 'generalchildrenshospital', 'academicchildrenshospital', 'effective]']
# 9
# Question: A short stay or 23-hour ward in a general and academic children's hospital: are they effective?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['Chilestrafficlawreform', 'trafficlawreform', 'Chile', 'trafficlaw', 'lawreform', 'policeenforcement', 'police', 'enforcement', 'reform', 'push.']
# 10
# Question: Did Chile's traffic law reform push police enforcement?
# Response: maybe
# Ground Truth: yes
#
#
# Question nodes: ['[therapeuticanticoagulation', 'traumapatient', 'safe]']
# 11
# Question: Therapeutic anticoagulation in the trauma patient: is it safe?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['Differentiation', 'nonalcoholicsteatohepatitis', 'alcoholicsteatohepatitis', 'routinelaboratorymarkers', 'useful']
# 12
# Question: Differentiation of nonalcoholic from alcoholic steatohepatitis: are routine laboratory markers useful?
# Response: maybe
# Ground Truth: yes
#
#
# Question nodes: ['PromptingPrimaryCareProviders', 'IncreasedPatientRisk', 'FamilyHistory', 'Work']
# 13
# Question: Prompting Primary Care Providers about Increased Patient Risk As a Result of Family History: Does It Work?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['emergencyultrasoundfellowshipprograms', 'impact', 'emergencymedicineresidents', 'ultrasoundeducation']
# 14
# Question: Do emergency ultrasound fellowship programs impact emergency medicine residents' ultrasound education?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Patient-ControlledTherapy', 'Therapy', 'Breathlessness', 'PalliativeCare', 'NewTherapeuticConcept', 'OpioidAdministration]']
# 15
# Question: Patient-Controlled Therapy of Breathlessness in Palliative Care: A New Therapeutic Concept for Opioid Administration?
# Response: yes
# Ground Truth: yes
#
#
# Question nodes: ['living-relatedlivertransplantation', 'need', 'children']
# 16
# Question: Is there still a need for living-related liver transplantation in children?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['patternsofknowledge', 'attitudes', 'unvaccinatedseniors']
# 17
# Question: Do patterns of knowledge and attitudes exist among unvaccinated seniors?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[model', 'teach', 'practice', 'retroperitoneoscopicnephrectomy', 'retroperitoneoscopic', 'nephrectomy]']
# 18
# Question: Is there a model to teach and practice retroperitoneoscopic nephrectomy?
# Response: yes
# Ground Truth: yes
#
#
# Question nodes: ['Cardiovascularrisk', 'ruraladult', 'WestAfricanpopulation', 'restingheartrate', 'relevant']
# 19
# Question: Cardiovascular risk in a rural adult West African population: is resting heart rate also relevant?
# Response: maybe
# Ground Truth: yes
#
#
# Question nodes: ['Israelihospital', 'preparedness', 'terrorism-related', 'multiplecasualtyincidents', 'surgecapacity', 'injuryseveritydistribution', 'betterpredicted']
# 20
# Question: Israeli hospital preparedness for terrorism-related multiple casualty incidents: can the surge capacity and injury severity distribution be better predicted?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Acuterespiratorydistresssyndrome', 'respiratorydistresssyndrome', 'children', 'malignancy', 'predictoutcome]']
# 21
# Question: Acute respiratory distress syndrome in children with malignancy--can we predict outcome?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[secondhandsmokerisk', 'infants', 'NICU', 'potential', 'significanthealthdisparities]']
# 22
# Question: Secondhand smoke risk in infants discharged from an NICU: potential for significant health disparities?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[nomograms', 'predictbiochemicalrecurrence', 'BCR', 'clinicallyrelevant', 'prostatecanceroutcomes]']
# 23
# Question: Do nomograms designed to predict biochemical recurrence (BCR) do a better job of predicting more clinically relevant prostate cancer outcomes than BCR?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[reports', 'mechanicaldysfunction', 'chronicoro-facialpain', 'somatisation]']
# 24
# Question: Are reports of mechanical dysfunction in chronic oro-facial pain related to somatisation?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Amblyopia', 'visualloss', 'permanent]']
# 25
# Question: Amblyopia: is visual loss permanent?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['[Implementationofepiduralanalgesia', 'epiduralanalgesia', 'labor', 'standardofeffectiveanalgesia', 'effectiveanalgesia', 'women]']
# 26
# Question: Implementation of epidural analgesia for labor: is the standard of effective analgesia reachable in all women?
# Response: yes
# Ground Truth: yes
#
#
# Question nodes: ['[HER2immunoreactivity', 'prognosticinformation', 'locallyadvancedurothelialcarcinoma', 'patients', 'adjuvantM-VECchemotherapy]']
# 27
# Question: Does HER2 immunoreactivity provide prognostic information in locally advanced urothelial carcinoma patients receiving adjuvant M-VEC chemotherapy?
# Response: no answer found
# Ground Truth: maybe
#
#
# Question nodes: ['halofantrine', 'ototoxic']
# 28
# Question: Is halofantrine ototoxic?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Visceraladiposetissueareameasurement', 'singlelevel', 'visceraladiposetissuevolume]']
# 29
# Question: Visceral adipose tissue area measurement at a single level: can it represent visceral adipose tissue volume?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['Necrotizingfasciitis', 'indication', 'hyperbaricoxygenationtherapy']
# 30
# Question: Necrotizing fasciitis: an indication for hyperbaric oxygenation therapy?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['[Hawkinssign', 'predictnecrosis', 'fractures', 'neckoftheastragalus]']
# 31
# Question: Is the Hawkins sign able to predict necrosis in fractures of the neck of the astragalus?
# Response: no answer found
# Ground Truth: maybe
#
#
# Question nodes: ['mandatorygeneralsurgeryrotation', 'generalsurgeryrotation', 'surgeryrotation', 'surgicalclerkship']
# 32
# Question: Is a mandatory general surgery rotation necessary in the surgical clerkship?
# Response: maybe
# Ground Truth: no
#
#
# Question nodes: ['Acupuncture', 'Efficacious', 'Treating', 'PhonotraumaticVocalPathologies']
# 33
# Question: Is Acupuncture Efficacious for Treating Phonotraumatic Vocal Pathologies?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['aneurysmrepair', 'patients', 'aged80orolder', 'aneurysmalsubarachnoidhemorrhage']
# 34
# Question: Is aneurysm repair justified for the patients aged 80 or older after aneurysmal subarachnoid hemorrhage?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[generalpracticecharacteristics', 'generalpractice', 'characteristics', 'influence', 'uptake', 'informationtechnology', 'ITinnovation', 'primarycare]']
# 35
# Question: Do general practice characteristics influence uptake of an information technology (IT) innovation in primary care?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['Prognosis', 'welldifferentiatedsmallhepatocellularcarcinoma', 'welldifferentiatedhepatocellularcarcinoma', 'earlycancer']
# 36
# Question: Prognosis of well differentiated small hepatocellular carcinoma--is well differentiated hepatocellular carcinoma clinically early cancer?
# Response: maybe
# Ground Truth: no
#
#
# Question nodes: ['[follow-uprecommendations', 'abnormalPapanicolaousmears', 'patientadherence]']
# 37
# Question: Do follow-up recommendations for abnormal Papanicolaou smears influence patient adherence?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['[Biomolecularidentification', 'allergenicpollen', 'newperspective', 'aerobiologicalmonitoring]']
# 38
# Question: Biomolecular identification of allergenic pollen: a new perspective for aerobiological monitoring?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['diabetesmellitus', 'efficacy', 'FDG-PET', 'diagnosis', 'cervicalcancer']
# 39
# Question: Does diabetes mellitus influence the efficacy of FDG-PET in the diagnosis of cervical cancer?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['Biomechanicalcharacteristics', 'woundhealingcharacteristics', 'corneas', 'excimerlaserkeratorefractivesurgery', 'difference', 'advancedsurfaceablation', 'sub-Bowmanskeratomileusis']
# 40
# Question: Biomechanical and wound healing characteristics of corneas after excimer laser keratorefractive surgery: is there a difference between advanced surface ablation and sub-Bowman's keratomileusis?
# Response: maybe
# Ground Truth: yes
#
#
# Question nodes: ['radiotherapy', 'primaryrectalcancer', 'prognosis', 'pelvicexenteration', 'recurrentrectalcancer']
# 41
# Question: Does radiotherapy of the primary rectal cancer affect prognosis after pelvic exenteration for recurrent rectal cancer?
# Response: no
# Ground Truth: yes
#
#
# Question nodes: ['practicingsurgeon', 'detectearlylymphedema', 'lymphedema', 'reliabledetection']
# 42
# Question: Can a practicing surgeon detect early lymphedema reliably?
# Response: no answer found
# Ground Truth: maybe
#
#
# Question nodes: ['[colorectalcancer', 'synchronouslivermetastases', 'globalmanagement', 'samecentre', 'improveresults]']
# 43
# Question: Colorectal cancer with synchronous liver metastases: does global management at the same centre improve results?
# Response: no answer found
# Ground Truth: no
#
#
# Question nodes: ['motionperceptiondeficit', 'schizophrenia', 'eye-trackingabnormality', 'consequence', 'entity', 'idea']
# 44
# Question: Is motion perception deficit in schizophrenia a consequence of eye-tracking abnormality?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Transgastricendoscopicsplenectomy', 'endoscopicsplenectomy', 'splenectomy]']
# 45
# Question: Transgastric endoscopic splenectomy: is it possible?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['[Fourniersgangrene', 'Fourniers', 'gangrene', 'dangerous]']
# 46
# Question: It's Fournier's gangrene still dangerous?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['implantkidneys', 'elderlydonors', 'youngrecipients']
# 47
# Question: Is it appropriate to implant kidneys from elderly donors in young recipients?
# Response: no answer found
# Ground Truth: yes
#
#
# Question nodes: ['providerservicenetworks', 'lowerexpenditures', 'HMOs', 'primarycarecasemanagement', 'FloridasMedicaidprogram']
# 48
# Question: Do provider service networks result in lower expenditures compared with HMOs or primary care case management in Florida's Medicaid program?
# Response: yes
# Ground Truth: yes
#
#
# Question nodes: ['Assessment', 'carotidarterystenosis', 'coronaryarterybypasssurgery', 'necessary']
# 49
# Question: Assessment of carotid artery stenosis before coronary artery bypass surgery. Is it always necessary?
# Response: no answer found
# Ground Truth: no
#
#
# Accuracy: 0.12
# Not found rate: 0.72
